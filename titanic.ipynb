# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
df_gender = pd.read_csv("/kaggle/input/titanic/gender_submission.csv")
df_test = pd.read_csv("/kaggle/input/titanic/test.csv")
df_train = pd.read_csv("/kaggle/input/titanic/train.csv")

# %%
df_gender
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df_test.head()
df_test.info()
df_train.head()
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(len(df_gender),len(df_train),len(df_test))
# Out:
# 418 891 418

# %%
df_train['Family'] = df_train['SibSp'] + df_train['Parch'] + 1

# %%
cols = ["Pclass", "Sex", "Age","SibSp","Parch","Fare","Embarked","Family"]
X_train = df_train[cols]
y_train = df_train["Survived"]

# %%
X_train.head()
# y_train.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Family
# 0       3    male  22.0      1      0   7.2500        S       2
# 1       1  female  38.0      1      0  71.2833        C       2
# 2       3  female  26.0      0      0   7.9250        S       1
# 3       1  female  35.0      1      0  53.1000        S       2
# 4       3    male  35.0      0      0   8.0500        S       1

# %%
X_train.isna().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# Family        0
# dtype: int64

# %%
X_train['Sex'].unique()
X_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
X_train.loc[:, 'Sex'] = X_train['Sex'].map({'male': 1, 'female': 2})

mean_age = X_train['Age'].mean()
X_train.loc[:, 'Age'] = X_train['Age'].fillna(mean_age)

most_embarked = df_train['Embarked'].mode()[0]
X_train.loc[:, 'Embarked'] = X_train['Embarked'].fillna(most_embarked)

X_train.loc[:, 'Embarked'] = X_train['Embarked'].map({'S': 1, 'C': 2, 'Q' : 3})
X_train
# Out:
#      Pclass Sex        Age  SibSp  Parch     Fare Embarked  Family
# 0         3   1  22.000000      1      0   7.2500        1       2
# 1         1   2  38.000000      1      0  71.2833        2       2
# 2         3   2  26.000000      0      0   7.9250        1       1
# 3         1   2  35.000000      1      0  53.1000        1       2
# 4         3   1  35.000000      0      0   8.0500        1       1
# ..      ...  ..        ...    ...    ...      ...      ...     ...
# 886       2   1  27.000000      0      0  13.0000        1       1
# 887       1   2  19.000000      0      0  30.0000        1       1
# 888       3   2  29.699118      1      2  23.4500        1       4
# 889       1   1  26.000000      0      0  30.0000        2       1
# 890       3   1  32.000000      0      0   7.7500        3       1
#
# [891 rows x 8 columns]

# %%
X_train.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Family      0
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
df_test['Family'] = df_test['SibSp'] + df_test['Parch'] + 1

# %%
# df_test['Sex'] = df_test['Sex'].map({'male': 1, 'female': 2})
X_test = df_test[cols]

# %%
X_test.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Family      0
# dtype: int64

# %%
X_test
# Out:
#      Pclass Sex       Age  SibSp  Parch      Fare Embarked  Family
# 0         3   1  34.50000      0      0    7.8292        3       1
# 1         3   2  47.00000      1      0    7.0000        1       2
# 2         2   1  62.00000      0      0    9.6875        3       1
# 3         3   1  27.00000      0      0    8.6625        1       1
# 4         3   2  22.00000      1      1   12.2875        1       3
# ..      ...  ..       ...    ...    ...       ...      ...     ...
# 413       3   1  30.27259      0      0    8.0500        1       1
# 414       1   2  39.00000      0      0  108.9000        2       1
# 415       3   1  38.50000      0      0    7.2500        1       1
# 416       3   1  30.27259      0      0    8.0500        1       1
# 417       3   1  30.27259      1      1   22.3583        2       3
#
# [418 rows x 8 columns]

# %%
X_test.loc[:, 'Sex'] = X_test['Sex'].map({'male': 1, 'female': 2})

mean_age = X_test['Age'].mean()
X_test.loc[:, 'Age'] = X_test['Age'].fillna(mean_age)

most_embarked = df_train['Embarked'].mode()[0]
X_test.loc[:, 'Embarked'] = X_test['Embarked'].fillna(most_embarked)

X_test.loc[:, 'Embarked'] = X_test['Embarked'].map({'S': 1, 'C': 2, 'Q' : 3})
X_test
# Out:
#      Pclass Sex       Age  SibSp  Parch      Fare Embarked  Family
# 0         3   1  34.50000      0      0    7.8292        3       1
# 1         3   2  47.00000      1      0    7.0000        1       2
# 2         2   1  62.00000      0      0    9.6875        3       1
# 3         3   1  27.00000      0      0    8.6625        1       1
# 4         3   2  22.00000      1      1   12.2875        1       3
# ..      ...  ..       ...    ...    ...       ...      ...     ...
# 413       3   1  30.27259      0      0    8.0500        1       1
# 414       1   2  39.00000      0      0  108.9000        2       1
# 415       3   1  38.50000      0      0    7.2500        1       1
# 416       3   1  30.27259      0      0    8.0500        1       1
# 417       3   1  30.27259      1      1   22.3583        2       3
#
# [418 rows x 8 columns]

# %%
mean_fare = X_test['Fare'].mean()
X_test.loc[:, 'Fare'] = X_test['Fare'].fillna(mean_fare)

# %%
prediction = model.predict(X_test)
len(prediction)
prediction


df_gender['Survived'] = prediction
df_gender.to_csv("submission.csv", index=False)

# %%
df_result = pd.read_csv("/kaggle/working/submission.csv")
df_result
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
